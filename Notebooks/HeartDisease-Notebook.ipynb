# %%
# Import data
import pandas as pd
df = pd.read_csv("../dataset/heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
# Features and target variables
X = df.drop("HeartDisease",axis=1)
y = df["HeartDisease"]

# %%
# Categorical variables 
X.ChestPainType.unique(), X.RestingECG.unique(), X.ExerciseAngina.unique() , X.ST_Slope.unique()
# Out:
# (array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object),
#  array(['Normal', 'ST', 'LVH'], dtype=object),
#  array(['N', 'Y'], dtype=object),
#  array(['Up', 'Flat', 'Down'], dtype=object))

# %%
# Missing values
X.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# dtype: int64

# %%
from sklearn import set_config
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import *
from sklearn.preprocessing import *
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from dense_transformer import DenseTransformer
import warnings
warnings.filterwarnings("ignore")

# Splitting features into categories and numerics
numerics = ["Age","RestingBP","Cholesterol","FastingBS","MaxHR","Oldpeak"]
categoricals = ["Sex","ChestPainType","RestingECG" , "ExerciseAngina"]
ordinals = ["ST_Slope"]


# Numeric transformer
num_transformer = Pipeline(steps=[
    ("Normalization", MinMaxScaler())
])
# Categorical transformation
cat_transformer = Pipeline(steps=[
    ("Encoder", OneHotEncoder())
])

ord_transformer = Pipeline(steps=[

     ("OrdinalEncoder" , OrdinalEncoder())
])


# Column transformer 
col_transformer = ColumnTransformer( transformers=[
    ("numeric", num_transformer, numerics),
    ("categorics", cat_transformer, categoricals),
    ("ordinals" , ord_transformer , ordinals)
])

#Dimensionality reduction
pca = PCA()
lda = LDA()

# Pipeline
pipe = Pipeline( steps=[
    ("preprocessing", col_transformer),
    ("dimensionReduction" , pca),
    ("model", LogisticRegression())
])
# Grid params
grid_params = {
    "dimensionReduction" : [pca,lda],
    "dimensionReduction__n_components" : range(1,11),
    "model__C" : range(1,11),
    "model__solver" : ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    "model__multi_class" : ['auto', 'ovr', 'multinomial']
}
# grid searching for K tuning
grid = GridSearchCV(pipe,grid_params)
# Diagram 
set_config(display="diagram")
grid
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('preprocessing',
#                                         ColumnTransformer(transformers=[('numeric',
#                                                                          Pipeline(steps=[('Normalization',
#                                                                                           MinMaxScaler())]),
#                                                                          ['Age',
#                                                                           'RestingBP',
#                                                                           'Cholesterol',
#                                                                           'FastingBS',
#                                                                           'MaxHR',
#                                                                           'Oldpeak']),
#                                                                         ('categorics',
#                                                                          Pipeline(steps=[('Encoder',
#                                                                                           OneHotEncoder())]),
#                                                                          ['Sex',
#                                                                           'ChestPainType',
#                                                                           'RestingECG',
#                                                                           'ExerciseAngina']),
#                                                                         ('ordinals',
#                                                                          Pipeline...
#                                                                                           OrdinalEncoder())]),
#                                                                          ['ST_Slope'])])),
#                                        ('dimensionReduction', PCA()),
#                                        ('model', LogisticRegression())]),
#              param_grid={'dimensionReduction': [PCA(),
#                                                 LinearDiscriminantAnalysis()],
#                          'dimensionReduction__n_components': range(1, 11),
#                          'model__C': range(1, 11),
#                          'model__multi_class': ['auto', 'ovr', 'multinomial'],
#                          'model__solver': ['newton-cg', 'lbfgs', 'liblinear',
#                                            'sag', 'saga']})

# %%
# Fitting the data to the grid search process
fitted = grid.fit(X,y)

# %%
# Inspecting results
result_df = pd.DataFrame(fitted.cv_results_).drop(["mean_fit_time","std_fit_time",
                                       "mean_score_time","std_score_time",
                                       "params","split0_test_score"	,"split1_test_score",
                                       "split2_test_score","split3_test_score","split4_test_score"],axis=1)

result_df.sort_values(by=["rank_test_score"])
# Out:
#           param_dimensionReduction param_dimensionReduction__n_components  \
# 458            PCA(n_components=4)                                      4
# 450            PCA(n_components=4)                                      4
# 451            PCA(n_components=4)                                      4
# 452            PCA(n_components=4)                                      4
# 453            PCA(n_components=4)                                      4
# ...                            ...                                    ...
# 2021  LinearDiscriminantAnalysis()                                      4
# 2020  LinearDiscriminantAnalysis()                                      4
# 2019  LinearDiscriminantAnalysis()                                      4
# 2017  LinearDiscriminantAnalysis()                                      4
# 2999  LinearDiscriminantAnalysis()                                     10
#
#      param_model__C param_model__multi_class param_model__solver  \
# 458               1                      ovr                 sag
# 450               1                     auto           newton-cg
# 451               1                     auto               lbfgs
# 452               1                     auto           liblinear
# 453               1                     auto                 sag
# ...             ...                      ...                 ...
# 2021              5              multinomial               lbfgs
# 2020              5              multinomial           newton-cg
# 2019              5                      ovr                saga
# 2017              5                      ovr           liblinear
# 2999             10              multinomial                saga
#
#       mean_test_score  std_test_score  rank_test_score
# 458          0.848521        0.048366                1
# 450          0.848521        0.048366                1
# 451          0.848521        0.048366                1
# 452          0.848521        0.048366                1
# 453          0.848521        0.048366                1
# ...               ...             ...              ...
# 2021              NaN             NaN             2996
# 2020              NaN             NaN             2997
# 2019              NaN             NaN             2998
# 2017              NaN             NaN             2999
# 2999              NaN             NaN             3000
#
# [3000 rows x 8 columns]

# %%
# Best parameters and best score
"Best parameters : " , fitted.best_params_ , "Best score : " , fitted.best_score_
# Out:
# ('Best parameters : ',
#  {'dimensionReduction': PCA(n_components=4),
#   'dimensionReduction__n_components': 4,
#   'model__C': 1,
#   'model__multi_class': 'auto',
#   'model__solver': 'newton-cg'},
#  'Best score : ',
#  0.84852102637206)

# %%
# Confusion matrix using the best estimator from the grid search
from sklearn.metrics import confusion_matrix
final_model = fitted.best_estimator_
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state = 0)
final_model.fit(X_train,y_train)
y_pred = final_model.predict(X_test)
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[62, 15],
#        [16, 91]])
